# %%
import pandas as pd
from sec_fundamentals import SecConfig, build_quarter_table
# Out:
# d:\Miniconda\envs\python3_12_F550\Lib\site-packages\requests\__init__.py:86: RequestsDependencyWarning: Unable to find acceptable character detection dependency (chardet or charset_normalizer).
#   warnings.warn(

# %%
cfg = SecConfig(user_agent='test xyz@gmail.com')
qt = build_quarter_table('NVDA', cfg)
print(qt[['end','filed','revenue','net_income','fcf']].tail(10).to_string())
# Out:
# Using tag: RevenueFromContractWithCustomerExcludingAssessedTax
# Using tag: EntityCommonStockSharesOutstanding
#           end      filed  revenue    net_income  fcf
# 49 2022-10-30 2023-11-21      NaN  6.800000e+08  NaN
# 50 2023-04-30 2024-05-29      NaN  2.043000e+09  NaN
# 51 2023-07-30 2024-08-28      NaN  6.188000e+09  NaN
# 52 2023-10-29 2024-11-20      NaN  9.243000e+09  NaN
# 53 2024-04-28 2025-05-28      NaN  1.488100e+10  NaN
# 54 2024-07-28 2025-08-27      NaN  1.659900e+10  NaN
# 55 2024-10-27 2025-11-19      NaN  1.930900e+10  NaN
# 56 2025-04-27 2025-05-28      NaN  1.877500e+10  NaN
# 57 2025-07-27 2025-08-27      NaN  2.642200e+10  NaN
# 58 2025-10-26 2025-11-19      NaN  3.191000e+10  NaN
